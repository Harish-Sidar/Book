# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("books.csv",error_bad_lines=False)
df2=pd.read_csv("books2.csv",error_bad_lines=False)
ratings=pd.read_csv("Ratings.csv",error_bad_lines=False)
user=pd.read_csv("Users.csv",error_bad_lines=False)
# Out:
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df1=pd.read_csv("books.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df1=pd.read_csv("books.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2=pd.read_csv("books2.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df2=pd.read_csv("books2.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("books2.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ratings=pd.read_csv("Ratings.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("books2.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   ratings=pd.read_csv("Ratings.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   user=pd.read_csv("Users.csv",error_bad_lines=False)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\615020521.py:4: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   user=pd.read_csv("Users.csv",error_bad_lines=False)

# %%
df1.shape
# Out:
# (52478, 25)
# (52478, 25)

# %%
df1=df1[df1['numRatings']>=500].sort_values('rating',ascending=False).head(15000)
df1.shape
# Out:
# (15000, 25)
# (15000, 25)

# %%
df1.head(5)
# Out:
#                                                   bookId  \
# 2488                50926309-100-bible-facts-about-jesus
# 43462             33649894-keeper-of-the-lost-cities-set
# 7737   24885561-keeper-of-the-lost-cities-exile-everb...
# 256                 24812.The_Complete_Calvin_and_Hobbes
# 32605            26112217-wings-of-fire-boxset-books-1-5
#
#                                                    title  \
# 2488   100 Bible Facts About Jesus: The Exciting way ...
# 43462                      Keeper of the Lost Cities Set
# 7737       Keeper of the Lost Cities / Exile / Everblaze
# 256                       The Complete Calvin and Hobbes
# 32605                    Wings of Fire Boxset, Books 1-5
#
#                                series  \
# 2488                              NaN
# 43462  Keeper of the Lost Cities #1-5
# 7737   Keeper of the Lost Cities #1-3
# 256                 Calvin and Hobbes
# 32605              Wings of Fire #1-5
#
#                                            author  rating  \
# 2488                                  Ginger Baum    4.96
# 43462        Shannon Messenger (Goodreads Author)    4.88
# 7737         Shannon Messenger (Goodreads Author)    4.86
# 256                                Bill Watterson    4.82
# 32605  Tui T. Sutherland, Bea Reiter (Translator)    4.81
#
#                                              description language  \
# 2488   To your avail, I have this fascinating book he...      NaN
# 43462  From Book 1: In this riveting debut, a telepat...  English
# 7737   A telepathic girl is the key to an unknown wor...      NaN
# 256    [ \n  Box Set\n | Book One | Book Two | Book T...  English
# 32605  The New York Times bestselling Wings of Fire s...  English
#
#                 isbn                                             genres  \
# 2488      B07XGFCBJX                                                 []
# 43462     B01FZFVDJG                                        ['Fantasy']
# 7737   9781481451123                        ['Fantasy', 'Middle Grade']
# 256    9780740748479  ['Comics', 'Humor', 'Graphic Novels', 'Fiction...
# 32605  9780545855723  ['Fantasy', 'Dragons', 'Young Adult', 'Childre...
#
#                  characters  ... firstPublishDate awards numRatings  \
# 2488                     []  ...              NaN     []        504
# 43462                    []  ...              NaN     []        694
# 7737                     []  ...              NaN     []        861
# 256    ['Calvin', 'Hobbes']  ...              NaN     []      34893
# 32605                    []  ...         08/01/15     []        600
#
#                                ratingsByStars likedPercent setting  \
# 2488              ['497', '2', '2', '0', '3']         99.0      []
# 43462            ['624', '60', '7', '2', '1']        100.0      []
# 7737            ['777', '60', '15', '3', '6']         99.0      []
# 256    ['30247', '3561', '782', '167', '136']         99.0      []
# 32605           ['527', '50', '11', '6', '6']         98.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 2488   https://i.gr-assets.com/images/S/compressed.ph...      1491       15
# 43462  https://i.gr-assets.com/images/S/compressed.ph...        74        1
# 7737   https://i.gr-assets.com/images/S/compressed.ph...       342        4
# 256    https://i.gr-assets.com/images/S/compressed.ph...     50709      632
# 32605  https://i.gr-assets.com/images/S/compressed.ph...        93        1
#
#         price
# 2488      NaN
# 43462     NaN
# 7737    23.98
# 256    110.67
# 32605   29.87
#
# [5 rows x 25 columns]
#                                                   bookId  \
# 2488                50926309-100-bible-facts-about-jesus
# 43462             33649894-keeper-of-the-lost-cities-set
# 7737   24885561-keeper-of-the-lost-cities-exile-everb...
# 256                 24812.The_Complete_Calvin_and_Hobbes
# 32605            26112217-wings-of-fire-boxset-books-1-5
#
#                                                    title  \
# 2488   100 Bible Facts About Jesus: The Exciting way ...
# 43462                      Keeper of the Lost Cities Set
# 7737       Keeper of the Lost Cities / Exile / Everblaze
# 256                       The Complete Calvin and Hobbes
# 32605                    Wings of Fire Boxset, Books 1-5
#
#                                series  \
# 2488                              NaN
# 43462  Keeper of the Lost Cities #1-5
# 7737   Keeper of the Lost Cities #1-3
# 256                 Calvin and Hobbes
# 32605              Wings of Fire #1-5
#
#                                            author  rating  \
# 2488                                  Ginger Baum    4.96
# 43462        Shannon Messenger (Goodreads Author)    4.88
# 7737         Shannon Messenger (Goodreads Author)    4.86
# 256                                Bill Watterson    4.82
# 32605  Tui T. Sutherland, Bea Reiter (Translator)    4.81
#
#                                              description language  \
# 2488   To your avail, I have this fascinating book he...      NaN
# 43462  From Book 1: In this riveting debut, a telepat...  English
# 7737   A telepathic girl is the key to an unknown wor...      NaN
# 256    [ \n  Box Set\n | Book One | Book Two | Book T...  English
# 32605  The New York Times bestselling Wings of Fire s...  English
#
#                 isbn                                             genres  \
# 2488      B07XGFCBJX                                                 []
# 43462     B01FZFVDJG                                        ['Fantasy']
# 7737   9781481451123                        ['Fantasy', 'Middle Grade']
# 256    9780740748479  ['Comics', 'Humor', 'Graphic Novels', 'Fiction...
# 32605  9780545855723  ['Fantasy', 'Dragons', 'Young Adult', 'Childre...
#
#                  characters  ... firstPublishDate awards numRatings  \
# 2488                     []  ...              NaN     []        504
# 43462                    []  ...              NaN     []        694
# 7737                     []  ...              NaN     []        861
# 256    ['Calvin', 'Hobbes']  ...              NaN     []      34893
# 32605                    []  ...         08/01/15     []        600
#
#                                ratingsByStars likedPercent setting  \
# 2488              ['497', '2', '2', '0', '3']         99.0      []
# 43462            ['624', '60', '7', '2', '1']        100.0      []
# 7737            ['777', '60', '15', '3', '6']         99.0      []
# 256    ['30247', '3561', '782', '167', '136']         99.0      []
# 32605           ['527', '50', '11', '6', '6']         98.0      []
#
#                                                 coverImg  bbeScore bbeVotes  \
# 2488   https://i.gr-assets.com/images/S/compressed.ph...      1491       15
# 43462  https://i.gr-assets.com/images/S/compressed.ph...        74        1
# 7737   https://i.gr-assets.com/images/S/compressed.ph...       342        4
# 256    https://i.gr-assets.com/images/S/compressed.ph...     50709      632
# 32605  https://i.gr-assets.com/images/S/compressed.ph...        93        1
#
#         price
# 2488      NaN
# 43462     NaN
# 7737    23.98
# 256    110.67
# 32605   29.87
#
# [5 rows x 25 columns]

# %%
books_with_genre=df1.drop([ 'characters','language',
                           'description','coverImg','series','likedPercent','awards',
                           "firstPublishDate","price","publishDate","edition","bbeScore","bbeVotes",
                           "setting","pages","bookFormat","ratingsByStars"],axis=1)

# %%
books_with_genre.columns
# Out:
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings'],
#       dtype='object')
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings'],
#       dtype='object')

# %%
# df4=df2.rename({'ISBN':'isbn','Book-Title':'title'}, axis=1)

# df4.columns
# df2=df2.dropna()

# %%
books_with_genre=books_with_genre.dropna()
books_with_genre.isnull().sum()
books_with_genre.columns
# Out:
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings'],
#       dtype='object')
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings'],
#       dtype='object')

# %%
books_with_genre=books_with_genre.drop_duplicates()
books_with_genre.duplicated().sum()
# Out:
# 0
# 0

# %%
from ast import literal_eval

from numpy import split


# data=books_with_genre['genres'].apply(lambda x:[literal_eval(x)])
# data
def convert(obj):
    return literal_eval(obj)

def convertToList(obj):
    return obj.split(',')

# %%
books_with_genre.iloc[0].publisher
# Out:
# 'Aladdin'
# 'Aladdin'

# %%
data=books_with_genre.iloc[6].author
data=data.split(',')
data
# Out:
# ['Mustafa Kemal Atatürk', ' Zeynep Korkmaz (Editor)']
# ['Mustafa Kemal Atatürk', ' Zeynep Korkmaz (Editor)']

# %%
# books_with_genre['genres'].apply(lambda x:[i.replace(" ","") for i in x])
books_with_genre['author']=books_with_genre['author'].apply(convertToList)
books_with_genre['publisher']=books_with_genre['publisher'].apply(convertToList)
books_with_genre['genres']=books_with_genre['genres'].apply(convert)

# %%
books_with_genre['genres']=books_with_genre['genres'].apply(lambda x:[i.replace(" ","") for i in x])
books_with_genre['author']=books_with_genre['author'].apply(lambda x:[i.replace(" ","") for i in x])
books_with_genre['publisher']=books_with_genre['publisher'].apply(lambda x:[i.replace(" ","") for i in x])

# %%
books_with_genre.iloc[6].author
# Out:
# ['MustafaKemalAtatürk', 'ZeynepKorkmaz(Editor)']
# ['MustafaKemalAtatürk', 'ZeynepKorkmaz(Editor)']

# %%
books_with_genre.iloc[6].publisher
# Out:
# ['AtatürkAraştırmaMerkezi']
# ['AtatürkAraştırmaMerkezi']

# %%
books_with_genre['tag']=books_with_genre['author']+books_with_genre['genres']+books_with_genre['publisher']

# %%
books_with_genre.head(2)
# Out:
#                                                   bookId  \
# 43462             33649894-keeper-of-the-lost-cities-set
# 7737   24885561-keeper-of-the-lost-cities-exile-everb...
#
#                                                title  \
# 43462                  Keeper of the Lost Cities Set
# 7737   Keeper of the Lost Cities / Exile / Everblaze
#
#                                     author  rating           isbn  \
# 43462  [ShannonMessenger(GoodreadsAuthor)]    4.88     B01FZFVDJG
# 7737   [ShannonMessenger(GoodreadsAuthor)]    4.86  9781481451123
#
#                        genres  publisher  numRatings  \
# 43462               [Fantasy]  [Aladdin]         694
# 7737   [Fantasy, MiddleGrade]  [Aladdin]         861
#
#                                                      tag
# 43462  [ShannonMessenger(GoodreadsAuthor), Fantasy, A...
# 7737   [ShannonMessenger(GoodreadsAuthor), Fantasy, M...
#                                                   bookId  \
# 43462             33649894-keeper-of-the-lost-cities-set
# 7737   24885561-keeper-of-the-lost-cities-exile-everb...
#
#                                                title  \
# 43462                  Keeper of the Lost Cities Set
# 7737   Keeper of the Lost Cities / Exile / Everblaze
#
#                                     author  rating           isbn  \
# 43462  [ShannonMessenger(GoodreadsAuthor)]    4.88     B01FZFVDJG
# 7737   [ShannonMessenger(GoodreadsAuthor)]    4.86  9781481451123
#
#                        genres  publisher  numRatings  \
# 43462               [Fantasy]  [Aladdin]         694
# 7737   [Fantasy, MiddleGrade]  [Aladdin]         861
#
#                                                      tag
# 43462  [ShannonMessenger(GoodreadsAuthor), Fantasy, A...
# 7737   [ShannonMessenger(GoodreadsAuthor), Fantasy, M...

# %%
books_with_genre.columns
# Out:
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings', 'tag'],
#       dtype='object')
# Index(['bookId', 'title', 'author', 'rating', 'isbn', 'genres', 'publisher',
#        'numRatings', 'tag'],
#       dtype='object')

# %%
new_df=books_with_genre[['bookId','title','isbn','rating','numRatings','tag']]

# %%
new_df['tag']=new_df['tag'].apply(lambda x:" ".join(x))
# Out:
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\4079141722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tag']=new_df['tag'].apply(lambda x:" ".join(x))
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\4079141722.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tag']=new_df['tag'].apply(lambda x:" ".join(x))

# %%
new_df.iloc[0].tag
# Out:
# 'ShannonMessenger(GoodreadsAuthor) Fantasy Aladdin'
# 'ShannonMessenger(GoodreadsAuthor) Fantasy Aladdin'

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():
        y.append(ps.stem(i)) 
    return " ".join(y)

# %%
new_df['tag']=new_df['tag'].apply(stem)
# Out:
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\599176683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tag']=new_df['tag'].apply(stem)
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\599176683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tag']=new_df['tag'].apply(stem)

# %% [markdown]
# ### Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df1.columns
# Out:
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')
# Index(['bookId', 'title', 'series', 'author', 'rating', 'description',
#        'language', 'isbn', 'genres', 'characters', 'bookFormat', 'edition',
#        'pages', 'publisher', 'publishDate', 'firstPublishDate', 'awards',
#        'numRatings', 'ratingsByStars', 'likedPercent', 'setting', 'coverImg',
#        'bbeScore', 'bbeVotes', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
sns.countplot(x= 'author',data=df1,order=df1['author'].value_counts().iloc[:10].index)
plt.title("Top 10 Authors")
plt.xlabel('Authors')
plt.ylabel('Number of Books')
plt.xticks(rotation=75,fontsize=12)
plt.show()

# %%
top_15_publisher = df1.groupby('publisher')['title'].count().reset_index().sort_values('title', ascending=False).head(15).set_index('publisher')
top_15_publisher.head(15)
# Out:
#                                        title
# publisher
# HarperCollins                            246
# Vintage                                  168
# Penguin Books                            132
# Del Rey                                  120
# VIZ Media LLC                            119
# Ballantine Books                         119
# Avon                                     115
# Bantam                                   108
# Little, Brown Books for Young Readers    104
# St. Martin's Press                       102
# Bethany House Publishers                  95
# Pocket Books                              86
# Grand Central Publishing                  85
# Berkley                                   84
# Scholastic Press                          84
#                                        title
# publisher
# HarperCollins                            246
# Vintage                                  168
# Penguin Books                            132
# Del Rey                                  120
# VIZ Media LLC                            119
# Ballantine Books                         119
# Avon                                     115
# Bantam                                   108
# Little, Brown Books for Young Readers    104
# St. Martin's Press                       102
# Bethany House Publishers                  95
# Pocket Books                              86
# Grand Central Publishing                  85
# Berkley                                   84
# Scholastic Press                          84

# %%
plt.figure(figsize=(15,10))
ax = sns.barplot(x=top_15_publisher['title'],y= top_15_publisher.index, palette='CMRmap_r')

ax.set_title("Top 15 publisher with most books")
ax.set_xlabel("Total number of books")
totals = []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
    ax.text(i.get_width()+.2, i.get_y()+.2,str(round(i.get_width())), fontsize=15,color='black')
plt.show()

# %% [markdown]
# ### Popularity Based Recommendation

# %%
popular=new_df[new_df['numRatings']>=10000].sort_values('rating',ascending=False).head(10)

# %%
popular
# Out:
#                                           bookId  \
# 256         24812.The_Complete_Calvin_and_Hobbes
# 26500           11221285-the-way-of-kings-part-2
# 7008          8.Harry_Potter_Boxed_Set_Books_1_5
# 2756                     5031805-esv-study-bible
# 2699              95602.Mark_of_the_Lion_Trilogy
# 5564                  24814.It_s_a_Magical_World
# 14496          70489.There_s_Treasure_Everywhere
# 635                   17332218-words-of-radiance
# 1565   59715.The_Authoritative_Calvin_and_Hobbes
# 3582   24815.The_Indispensable_Calvin_and_Hobbes
#
#                                                    title           isbn  \
# 256                       The Complete Calvin and Hobbes  9780740748479
# 26500                           The Way of Kings, Part 2  9780575102484
# 7008   Harry Potter Boxed Set, Books 1-5 (Harry Potte...  9780439682589
# 2756                                     ESV Study Bible  9781433502415
# 2699                            Mark of the Lion Trilogy  9780842339520
# 5564                                It's a Magical World  9780836221367
# 14496                        There's Treasure Everywhere  9780836213126
# 635                                    Words of Radiance  9780765326362
# 1565   The Authoritative Calvin and Hobbes: A Calvin ...  9780751507959
# 3582                 The Indispensable Calvin and Hobbes  9780751500288
#
#        rating  numRatings                                                tag
# 256      4.82       34893  billwatterson comic humor graphicnovel fiction...
# 26500    4.79       13194  brandonsanderson(goodreadsauthor) fantasi fict...
# 7008     4.78       52749  j.k.rowl marygrandpré(illustrator) fantasi you...
# 2756     4.78       12868  anonym lanet.dennis(editor) waynegrudem(editor...
# 2699     4.77       11402  francinerivers(goodreadsauthor) christianfict ...
# 5564     4.76       25874  billwatterson comic humor graphicnovel fiction...
# 14496    4.75       19726  billwatterson comic humor fiction graphicnovel...
# 635      4.75      207369  brandonsanderson(goodreadsauthor) fantasi fict...
# 1565     4.74       20857  billwatterson comic humor graphicnovel fiction...
# 3582     4.74       19492  billwatterson comic humor fiction graphicnovel...
#                                           bookId  \
# 256         24812.The_Complete_Calvin_and_Hobbes
# 26500           11221285-the-way-of-kings-part-2
# 7008          8.Harry_Potter_Boxed_Set_Books_1_5
# 2756                     5031805-esv-study-bible
# 2699              95602.Mark_of_the_Lion_Trilogy
# 5564                  24814.It_s_a_Magical_World
# 14496          70489.There_s_Treasure_Everywhere
# 635                   17332218-words-of-radiance
# 1565   59715.The_Authoritative_Calvin_and_Hobbes
# 3582   24815.The_Indispensable_Calvin_and_Hobbes
#
#                                                    title           isbn  \
# 256                       The Complete Calvin and Hobbes  9780740748479
# 26500                           The Way of Kings, Part 2  9780575102484
# 7008   Harry Potter Boxed Set, Books 1-5 (Harry Potte...  9780439682589
# 2756                                     ESV Study Bible  9781433502415
# 2699                            Mark of the Lion Trilogy  9780842339520
# 5564                                It's a Magical World  9780836221367
# 14496                        There's Treasure Everywhere  9780836213126
# 635                                    Words of Radiance  9780765326362
# 1565   The Authoritative Calvin and Hobbes: A Calvin ...  9780751507959
# 3582                 The Indispensable Calvin and Hobbes  9780751500288
#
#        rating  numRatings                                                tag
# 256      4.82       34893  billwatterson comic humor graphicnovel fiction...
# 26500    4.79       13194  brandonsanderson(goodreadsauthor) fantasi fict...
# 7008     4.78       52749  j.k.rowl marygrandpré(illustrator) fantasi you...
# 2756     4.78       12868  anonym lanet.dennis(editor) waynegrudem(editor...
# 2699     4.77       11402  francinerivers(goodreadsauthor) christianfict ...
# 5564     4.76       25874  billwatterson comic humor graphicnovel fiction...
# 14496    4.75       19726  billwatterson comic humor fiction graphicnovel...
# 635      4.75      207369  brandonsanderson(goodreadsauthor) fantasi fict...
# 1565     4.74       20857  billwatterson comic humor graphicnovel fiction...
# 3582     4.74       19492  billwatterson comic humor fiction graphicnovel...

# %%
plt.style.use('seaborn-whitegrid')
plt.figure(figsize=(10, 10))

data = popular.sort_values(by='rating', ascending=False).head(10)
gr = sns.barplot(x=data['rating'], y="title", data=data, palette="CMRmap_r")
plt.xlabel('Avg_Rating')
plt.ylabel("Top 10 Books")
plt.yticks(rotation=10)
for i in gr.patches:
    gr.text(i.get_width() + .05, i.get_y() + 0.5, str(i.get_width()), fontsize = 10, color = 'k')
plt.show()
# Out:
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\1061937486.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')
# C:\Users\hk265\AppData\Local\Temp\ipykernel_13028\1061937486.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Content Base Recommendation

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=1000,stop_words='english')

# %%
new_df=new_df.reset_index()
vectors=cv.fit_transform(new_df['tag']).toarray()
new_df.shape
# Out:
# (14101, 7)
# (14101, 7)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)
# similarity=model_knn.fit(vectors)

# %%
def recommend(book):
    book_index=new_df[new_df['title']==book].index[0]
    distance=similarity[book_index]
    book_list=sorted(list(enumerate(distance)),reverse=True ,key=lambda x:x[1])[1:11]
    for i in book_list:
        print(new_df.iloc[i[0]].title)

# %%
recommend('The Final Empire')
# Out:
# The Well of Ascension
# Words of Radiance
# The Way of Kings
# The Way of Kings
# Oathbringer
# The Hero of Ages
# A Memory of Light
# The Gathering Storm
# The Way of Kings
# Warbreaker
# The Well of Ascension
# Words of Radiance
# The Way of Kings
# The Way of Kings
# Oathbringer
# The Hero of Ages
# A Memory of Light
# The Gathering Storm
# The Way of Kings
# Warbreaker

# %% [markdown]
# ### Collaborative Filtering Based Recommender

# %%
df2.columns
df2=df2.drop(['Year-Of-Publication','Image-URL-S', 'Image-URL-M', 'Image-URL-L'],axis=1)
rating_with_name=ratings.merge(df2, on='ISBN')

# %%
rating_with_name = rating_with_name.dropna(axis = 0, subset = ['Book-Title'])

book_ratingCount = (rating_with_name.
    groupby(by = ['Book-Title'])['Book-Rating'].
    count().
    reset_index().
    rename(columns = {'Book-Rating': 'totalRatingCount'})
    [['Book-Title', 'totalRatingCount']]
    )
book_ratingCount.head()
# Out:
#                                           Book-Title  totalRatingCount
# 0   A Light in the Storm: The Civil War Diary of ...                 4
# 1                              Always Have Popsicles                 1
# 2               Apple Magic (The Collector's series)                 1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                 1
# 4   Beyond IBM: Leadership Marketing and Finance ...                 1
#                                           Book-Title  totalRatingCount
# 0   A Light in the Storm: The Civil War Diary of ...                 4
# 1                              Always Have Popsicles                 1
# 2               Apple Magic (The Collector's series)                 1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...                 1
# 4   Beyond IBM: Leadership Marketing and Finance ...                 1

# %%
rating_with_totalRatingCount = rating_with_name.merge(book_ratingCount, left_on = 'Book-Title', right_on = 'Book-Title', how = 'left')
rating_with_totalRatingCount.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#           Publisher  totalRatingCount
# 0  Ballantine Books                60
# 1  Ballantine Books                60
# 2  Ballantine Books                60
# 3  Ballantine Books                60
# 4  Ballantine Books                60
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#           Publisher  totalRatingCount
# 0  Ballantine Books                60
# 1  Ballantine Books                60
# 2  Ballantine Books                60
# 3  Ballantine Books                60
# 4  Ballantine Books                60

# %%
popularity_threshold = 50
rating_popular_book = rating_with_totalRatingCount.query('totalRatingCount >= @popularity_threshold')
rating_popular_book.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#           Publisher  totalRatingCount
# 0  Ballantine Books                60
# 1  Ballantine Books                60
# 2  Ballantine Books                60
# 3  Ballantine Books                60
# 4  Ballantine Books                60
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#           Publisher  totalRatingCount
# 0  Ballantine Books                60
# 1  Ballantine Books                60
# 2  Ballantine Books                60
# 3  Ballantine Books                60
# 4  Ballantine Books                60

# %%
combined = rating_popular_book.merge(user, left_on = 'User-ID', right_on = 'User-ID', how = 'left')

us_canada_user_rating = combined[combined['Location'].str.contains("india|canada")]
us_canada_user_rating=us_canada_user_rating.drop('Age', axis=1)
us_canada_user_rating.head()
# Out:
#      User-ID        ISBN  Book-Rating    Book-Title      Book-Author  \
# 73     24878  0446520802            7  The Notebook  Nicholas Sparks
# 75     27617  0446520802            9  The Notebook  Nicholas Sparks
# 76     28204  0446520802            0  The Notebook  Nicholas Sparks
# 121   157823  0446520802           10  The Notebook  Nicholas Sparks
# 133   188010  0446520802            0  The Notebook  Nicholas Sparks
#
#         Publisher  totalRatingCount                         Location
# 73   Warner Books               650          ottawa, ontario, canada
# 75   Warner Books               650       beaverton, ontario, canada
# 76   Warner Books               650  south ohio, nova scotia, canada
# 121  Warner Books               650          guelph, ontario, canada
# 133  Warner Books               650        edmonton, alberta, canada
#      User-ID        ISBN  Book-Rating    Book-Title      Book-Author  \
# 73     24878  0446520802            7  The Notebook  Nicholas Sparks
# 75     27617  0446520802            9  The Notebook  Nicholas Sparks
# 76     28204  0446520802            0  The Notebook  Nicholas Sparks
# 121   157823  0446520802           10  The Notebook  Nicholas Sparks
# 133   188010  0446520802            0  The Notebook  Nicholas Sparks
#
#         Publisher  totalRatingCount                         Location
# 73   Warner Books               650          ottawa, ontario, canada
# 75   Warner Books               650       beaverton, ontario, canada
# 76   Warner Books               650  south ohio, nova scotia, canada
# 121  Warner Books               650          guelph, ontario, canada
# 133  Warner Books               650        edmonton, alberta, canada

# %% [markdown]
# ### Model Building

# %%
from scipy.sparse import csr_matrix
us_canada_user_rating = us_canada_user_rating.drop_duplicates(['User-ID', 'Book-Title'])
us_canada_user_rating_pivot = us_canada_user_rating.pivot(index = 'Book-Title', columns = 'User-ID', values = 'Book-Rating').fillna(0)
us_canada_user_rating_matrix = csr_matrix(us_canada_user_rating_pivot.values)

from sklearn.neighbors import NearestNeighbors

model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(us_canada_user_rating_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index = np.random.choice(us_canada_user_rating_pivot.shape[0])
distances, indices = model_knn.kneighbors(us_canada_user_rating_pivot.iloc[query_index,:].values.reshape(1,-1), n_neighbors = 6)

for i in range(0,6):
    if i == 0:
        print('Recommendations for {0}:\n'.format(us_canada_user_rating_pivot.index[query_index]))
    else:
        print('{0}: {1}'.format(i, us_canada_user_rating_pivot.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for The Westing Game (Now in Speak!):
#
# 1: Sunset in St. Tropez
# 2: Survival of the Fittest: An Alex Delaware Novel
# 3: Sushi for Beginners
# 4: Superstitious
# 5: Sun Also Rises
# Recommendations for The Westing Game (Now in Speak!):
#
# 1: Sunset in St. Tropez
# 2: Survival of the Fittest: An Alex Delaware Novel
# 3: Sushi for Beginners
# 4: Superstitious
# 5: Sun Also Rises
